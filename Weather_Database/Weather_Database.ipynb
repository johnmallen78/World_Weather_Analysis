# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | airai
# Processing Record 4 of Set 1 | ostrovnoy
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | yellowknife
# Processing Record 7 of Set 1 | la ronge
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | havelock
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | coquimbo
# Processing Record 13 of Set 1 | kyakhta
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | padang
# Processing Record 16 of Set 1 | luderitz
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | ancud
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | inirida
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | tahta
# Processing Record 23 of Set 1 | mar del plata
# Processing Record 24 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 1 | farafangana
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | weatherford
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | yialos
# City not found. Skipping...
# Processing Record 31 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 32 of Set 1 | khormuj
# City not found. Skipping...
# Processing Record 33 of Set 1 | asyut
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | poum
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | severo-yeniseyskiy
# Processing Record 39 of Set 1 | dhidhdhoo
# Processing Record 40 of Set 1 | korem
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | bengkulu
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 1 | impfondo
# Processing Record 49 of Set 1 | tura
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | pokhara
# Processing Record 2 of Set 2 | stromness
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | lorengau
# Processing Record 6 of Set 2 | monrovia
# Processing Record 7 of Set 2 | rio grande
# Processing Record 8 of Set 2 | constitucion
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | rikitea
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | port lincoln
# Processing Record 16 of Set 2 | khorol
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | turinsk
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | obera
# Processing Record 21 of Set 2 | katherine
# Processing Record 22 of Set 2 | arraial do cabo
# Processing Record 23 of Set 2 | sao sebastiao
# Processing Record 24 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 2 | sheridan
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | pevek
# Processing Record 28 of Set 2 | fomboni
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | fairbanks
# Processing Record 32 of Set 2 | emba
# Processing Record 33 of Set 2 | kendari
# Processing Record 34 of Set 2 | pochutla
# Processing Record 35 of Set 2 | waitati
# Processing Record 36 of Set 2 | grindavik
# Processing Record 37 of Set 2 | agua verde
# Processing Record 38 of Set 2 | montevideo
# Processing Record 39 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 2 | sikourion
# City not found. Skipping...
# Processing Record 41 of Set 2 | biak
# Processing Record 42 of Set 2 | praya
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | xuddur
# Processing Record 47 of Set 2 | hilo
# Processing Record 48 of Set 2 | dutse
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 2 | swan hill
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | kulob
# Processing Record 3 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 3 | busselton
# Processing Record 5 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 3 | saint-augustin
# Processing Record 7 of Set 3 | kieta
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | assela
# City not found. Skipping...
# Processing Record 10 of Set 3 | thessalon
# Processing Record 11 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 3 | guayabal
# Processing Record 13 of Set 3 | khandyga
# Processing Record 14 of Set 3 | paka
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | nhulunbuy
# Processing Record 17 of Set 3 | la palma
# Processing Record 18 of Set 3 | karamken
# City not found. Skipping...
# Processing Record 19 of Set 3 | la vega
# Processing Record 20 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 3 | carballo
# Processing Record 22 of Set 3 | liverpool
# Processing Record 23 of Set 3 | tutin
# Processing Record 24 of Set 3 | zlobin
# Processing Record 25 of Set 3 | arman
# Processing Record 26 of Set 3 | bethel
# Processing Record 27 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | uruzgan
# Processing Record 31 of Set 3 | hamilton
# Processing Record 32 of Set 3 | khatanga
# Processing Record 33 of Set 3 | meulaboh
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | khuzdar
# Processing Record 36 of Set 3 | banamba
# Processing Record 37 of Set 3 | juba
# Processing Record 38 of Set 3 | gladstone
# Processing Record 39 of Set 3 | haines junction
# Processing Record 40 of Set 3 | oistins
# Processing Record 41 of Set 3 | dakar
# Processing Record 42 of Set 3 | san cristobal
# Processing Record 43 of Set 3 | asau
# Processing Record 44 of Set 3 | hualmay
# Processing Record 45 of Set 3 | sao filipe
# Processing Record 46 of Set 3 | tuktoyaktuk
# Processing Record 47 of Set 3 | dauphin
# Processing Record 48 of Set 3 | kavieng
# Processing Record 49 of Set 3 | otjimbingwe
# Processing Record 50 of Set 3 | antalaha
# Processing Record 1 of Set 4 | cockburn town
# Processing Record 2 of Set 4 | rincon
# Processing Record 3 of Set 4 | provideniya
# Processing Record 4 of Set 4 | new norfolk
# Processing Record 5 of Set 4 | ladario
# Processing Record 6 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | baijiantan
# Processing Record 8 of Set 4 | chokurdakh
# Processing Record 9 of Set 4 | yantongshan
# Processing Record 10 of Set 4 | aleksandrovsk-sakhalinskiy
# Processing Record 11 of Set 4 | port alfred
# Processing Record 12 of Set 4 | cabo san lucas
# Processing Record 13 of Set 4 | porto walter
# Processing Record 14 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 15 of Set 4 | kannur
# Processing Record 16 of Set 4 | anloga
# Processing Record 17 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 4 | ponta do sol
# Processing Record 20 of Set 4 | college
# Processing Record 21 of Set 4 | lugovoy
# Processing Record 22 of Set 4 | keti bandar
# Processing Record 23 of Set 4 | sedalia
# Processing Record 24 of Set 4 | buncrana
# Processing Record 25 of Set 4 | salalah
# Processing Record 26 of Set 4 | novikovo
# Processing Record 27 of Set 4 | la asuncion
# Processing Record 28 of Set 4 | koungheul
# Processing Record 29 of Set 4 | domoni
# Processing Record 30 of Set 4 | celestun
# Processing Record 31 of Set 4 | tay ninh
# Processing Record 32 of Set 4 | niteroi
# Processing Record 33 of Set 4 | launceston
# Processing Record 34 of Set 4 | hambantota
# Processing Record 35 of Set 4 | saint george
# Processing Record 36 of Set 4 | guerrero negro
# Processing Record 37 of Set 4 | yulara
# Processing Record 38 of Set 4 | arona
# Processing Record 39 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 4 | lagoa
# Processing Record 41 of Set 4 | mbaiki
# Processing Record 42 of Set 4 | porto novo
# Processing Record 43 of Set 4 | noshiro
# Processing Record 44 of Set 4 | camopi
# Processing Record 45 of Set 4 | road town
# Processing Record 46 of Set 4 | cururupu
# Processing Record 47 of Set 4 | touros
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | portsmouth
# Processing Record 50 of Set 4 | maldonado
# Processing Record 1 of Set 5 | ucluelet
# Processing Record 2 of Set 5 | canavieiras
# Processing Record 3 of Set 5 | ambilobe
# Processing Record 4 of Set 5 | marrakesh
# Processing Record 5 of Set 5 | itaituba
# Processing Record 6 of Set 5 | nantucket
# Processing Record 7 of Set 5 | lata
# Processing Record 8 of Set 5 | grand gaube
# Processing Record 9 of Set 5 | anshun
# Processing Record 10 of Set 5 | mamaku
# Processing Record 11 of Set 5 | vostok
# Processing Record 12 of Set 5 | bezlyudivka
# Processing Record 13 of Set 5 | mansa
# Processing Record 14 of Set 5 | delmas
# Processing Record 15 of Set 5 | victoria
# Processing Record 16 of Set 5 | torbay
# Processing Record 17 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 5 | sinnamary
# Processing Record 20 of Set 5 | namibe
# Processing Record 21 of Set 5 | rocha
# Processing Record 22 of Set 5 | arlit
# Processing Record 23 of Set 5 | lilongwe
# Processing Record 24 of Set 5 | paamiut
# Processing Record 25 of Set 5 | bayonet point
# Processing Record 26 of Set 5 | bambanglipuro
# Processing Record 27 of Set 5 | vardo
# Processing Record 28 of Set 5 | andenes
# Processing Record 29 of Set 5 | maracacume
# Processing Record 30 of Set 5 | mackay
# Processing Record 31 of Set 5 | te anau
# Processing Record 32 of Set 5 | katsuura
# Processing Record 33 of Set 5 | ornskoldsvik
# Processing Record 34 of Set 5 | zhongshu
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | dingle
# Processing Record 37 of Set 5 | bozuyuk
# Processing Record 38 of Set 5 | ribeira grande
# Processing Record 39 of Set 5 | ussel
# Processing Record 40 of Set 5 | valparaiso
# Processing Record 41 of Set 5 | taksimo
# Processing Record 42 of Set 5 | zhanaozen
# Processing Record 43 of Set 5 | isagarh
# Processing Record 44 of Set 5 | ginir
# Processing Record 45 of Set 5 | coos bay
# Processing Record 46 of Set 5 | belluno
# Processing Record 47 of Set 5 | novooleksiyivka
# Processing Record 48 of Set 5 | demmin
# Processing Record 49 of Set 5 | sola
# Processing Record 50 of Set 5 | hami
# Processing Record 1 of Set 6 | narsaq
# Processing Record 2 of Set 6 | rabak
# Processing Record 3 of Set 6 | laguna
# Processing Record 4 of Set 6 | champerico
# Processing Record 5 of Set 6 | sideropolis
# Processing Record 6 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 7 of Set 6 | santa elena
# Processing Record 8 of Set 6 | eston
# Processing Record 9 of Set 6 | kodiak
# Processing Record 10 of Set 6 | alta floresta
# Processing Record 11 of Set 6 | chalinze
# Processing Record 12 of Set 6 | fort-shevchenko
# Processing Record 13 of Set 6 | cidreira
# Processing Record 14 of Set 6 | kismayo
# Processing Record 15 of Set 6 | bowen
# Processing Record 16 of Set 6 | opuwo
# Processing Record 17 of Set 6 | port hedland
# Processing Record 18 of Set 6 | trincomalee
# Processing Record 19 of Set 6 | lewiston
# Processing Record 20 of Set 6 | mayo
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | kaeo
# Processing Record 23 of Set 6 | turukhansk
# Processing Record 24 of Set 6 | calolbon
# Processing Record 25 of Set 6 | ponta delgada
# Processing Record 26 of Set 6 | riyadh
# Processing Record 27 of Set 6 | yashkul
# Processing Record 28 of Set 6 | fortuna
# Processing Record 29 of Set 6 | carnarvon
# Processing Record 30 of Set 6 | kloulklubed
# Processing Record 31 of Set 6 | sitka
# Processing Record 32 of Set 6 | vao
# Processing Record 33 of Set 6 | qui nhon
# Processing Record 34 of Set 6 | henties bay
# Processing Record 35 of Set 6 | marsciano
# Processing Record 36 of Set 6 | clarence town
# Processing Record 37 of Set 6 | mahuva
# Processing Record 38 of Set 6 | vanimo
# Processing Record 39 of Set 6 | alamo
# Processing Record 40 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 41 of Set 6 | novyy urengoy
# Processing Record 42 of Set 6 | saldanha
# Processing Record 43 of Set 6 | tigzirt
# Processing Record 44 of Set 6 | mahebourg
# Processing Record 45 of Set 6 | norman wells
# Processing Record 46 of Set 6 | norrtalje
# Processing Record 47 of Set 6 | anadyr
# Processing Record 48 of Set 6 | gigmoto
# Processing Record 49 of Set 6 | tuatapere
# Processing Record 50 of Set 6 | basco
# Processing Record 1 of Set 7 | asfi
# Processing Record 2 of Set 7 | ahuimanu
# Processing Record 3 of Set 7 | maniitsoq
# Processing Record 4 of Set 7 | dunedin
# Processing Record 5 of Set 7 | bereda
# Processing Record 6 of Set 7 | horodnye
# Processing Record 7 of Set 7 | maputo
# Processing Record 8 of Set 7 | znamenskoye
# Processing Record 9 of Set 7 | waddan
# Processing Record 10 of Set 7 | mabaruma
# Processing Record 11 of Set 7 | vestmannaeyjar
# Processing Record 12 of Set 7 | ballina
# Processing Record 13 of Set 7 | kysyl-syr
# Processing Record 14 of Set 7 | biltine
# Processing Record 15 of Set 7 | oneonta
# Processing Record 16 of Set 7 | badiraguato
# Processing Record 17 of Set 7 | nouadhibou
# Processing Record 18 of Set 7 | iqaluit
# Processing Record 19 of Set 7 | half moon bay
# Processing Record 20 of Set 7 | puerto colombia
# Processing Record 21 of Set 7 | guangyuan
# Processing Record 22 of Set 7 | mehamn
# Processing Record 23 of Set 7 | yumen
# Processing Record 24 of Set 7 | kijang
# Processing Record 25 of Set 7 | chapeco
# Processing Record 26 of Set 7 | husavik
# Processing Record 27 of Set 7 | phangnga
# Processing Record 28 of Set 7 | chimore
# Processing Record 29 of Set 7 | agnibilekrou
# Processing Record 30 of Set 7 | oktyabrskoye
# Processing Record 31 of Set 7 | sao felix do xingu
# Processing Record 32 of Set 7 | itarema
# Processing Record 33 of Set 7 | carutapera
# Processing Record 34 of Set 7 | kupang
# Processing Record 35 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 7 | isangel
# Processing Record 37 of Set 7 | superior
# Processing Record 38 of Set 7 | faya
# Processing Record 39 of Set 7 | sur
# Processing Record 40 of Set 7 | wucheng
# Processing Record 41 of Set 7 | yar-sale
# Processing Record 42 of Set 7 | yingcheng
# Processing Record 43 of Set 7 | gao
# Processing Record 44 of Set 7 | quata
# Processing Record 45 of Set 7 | roald
# Processing Record 46 of Set 7 | waterloo
# Processing Record 47 of Set 7 | doha
# Processing Record 48 of Set 7 | severo-kurilsk
# Processing Record 49 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 50 of Set 7 | tete
# Processing Record 1 of Set 8 | ixtapa
# Processing Record 2 of Set 8 | haimen
# Processing Record 3 of Set 8 | shipunovo
# Processing Record 4 of Set 8 | ilulissat
# Processing Record 5 of Set 8 | abu kamal
# Processing Record 6 of Set 8 | komsomolskiy
# Processing Record 7 of Set 8 | dahanu
# Processing Record 8 of Set 8 | merrill
# Processing Record 9 of Set 8 | bashtanka
# Processing Record 10 of Set 8 | viseu
# Processing Record 11 of Set 8 | kortkeros
# Processing Record 12 of Set 8 | krasnoselkup
# Processing Record 13 of Set 8 | rawson
# Processing Record 14 of Set 8 | piacabucu
# Processing Record 15 of Set 8 | umm kaddadah
# Processing Record 16 of Set 8 | honiara
# Processing Record 17 of Set 8 | zarichne
# Processing Record 18 of Set 8 | mlawa
# Processing Record 19 of Set 8 | mareeba
# Processing Record 20 of Set 8 | orizona
# Processing Record 21 of Set 8 | benguela
# Processing Record 22 of Set 8 | chala
# Processing Record 23 of Set 8 | mecca
# Processing Record 24 of Set 8 | pingliang
# Processing Record 25 of Set 8 | jomalig
# City not found. Skipping...
# Processing Record 26 of Set 8 | pindiga
# Processing Record 27 of Set 8 | yaan
# Processing Record 28 of Set 8 | luena
# Processing Record 29 of Set 8 | phrae
# Processing Record 30 of Set 8 | kudahuvadhoo
# Processing Record 31 of Set 8 | buraydah
# Processing Record 32 of Set 8 | samagaltay
# Processing Record 33 of Set 8 | carroll
# Processing Record 34 of Set 8 | lavrentiya
# Processing Record 35 of Set 8 | itoman
# Processing Record 36 of Set 8 | wanning
# Processing Record 37 of Set 8 | vygonichi
# Processing Record 38 of Set 8 | guozhen
# Processing Record 39 of Set 8 | port-cartier
# Processing Record 40 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 8 | burica
# City not found. Skipping...
# Processing Record 42 of Set 8 | samarai
# Processing Record 43 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 8 | bilibino
# Processing Record 45 of Set 8 | barquisimeto
# Processing Record 46 of Set 8 | zemio
# Processing Record 47 of Set 8 | la paz centro
# Processing Record 48 of Set 8 | darhan
# Processing Record 49 of Set 8 | san patricio
# Processing Record 50 of Set 8 | gaoua
# Processing Record 1 of Set 9 | balikpapan
# Processing Record 2 of Set 9 | itupiranga
# Processing Record 3 of Set 9 | kikwit
# Processing Record 4 of Set 9 | gumushane
# City not found. Skipping...
# Processing Record 5 of Set 9 | rivers
# Processing Record 6 of Set 9 | adrar
# Processing Record 7 of Set 9 | portland
# Processing Record 8 of Set 9 | skiros
# City not found. Skipping...
# Processing Record 9 of Set 9 | semey
# Processing Record 10 of Set 9 | skaelskor
# Processing Record 11 of Set 9 | vila franca do campo
# Processing Record 12 of Set 9 | niono
# Processing Record 13 of Set 9 | kuandian
# Processing Record 14 of Set 9 | galveston
# Processing Record 15 of Set 9 | hasaki
# Processing Record 16 of Set 9 | cartagena
# Processing Record 17 of Set 9 | bundi
# Processing Record 18 of Set 9 | derzhavinsk
# Processing Record 19 of Set 9 | kholmogory
# Processing Record 20 of Set 9 | nuuk
# Processing Record 21 of Set 9 | mongoumba
# Processing Record 22 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 9 | shevchenkove
# Processing Record 24 of Set 9 | kon tum
# Processing Record 25 of Set 9 | masloc
# Processing Record 26 of Set 9 | chimbarongo
# Processing Record 27 of Set 9 | slavsk
# Processing Record 28 of Set 9 | sioux lookout
# Processing Record 29 of Set 9 | chaihe
# Processing Record 30 of Set 9 | belgrade
# Processing Record 31 of Set 9 | weston
# Processing Record 32 of Set 9 | gat
# Processing Record 33 of Set 9 | chiang kham
# Processing Record 34 of Set 9 | raga
# Processing Record 35 of Set 9 | sorland
# Processing Record 36 of Set 9 | yabelo
# Processing Record 37 of Set 9 | wa
# City not found. Skipping...
# Processing Record 38 of Set 9 | coahuayana
# Processing Record 39 of Set 9 | thinadhoo
# Processing Record 40 of Set 9 | nacala
# Processing Record 41 of Set 9 | mayor pablo lagerenza
# Processing Record 42 of Set 9 | orlik
# Processing Record 43 of Set 9 | hrubieszow
# Processing Record 44 of Set 9 | talnakh
# Processing Record 45 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 46 of Set 9 | tiksi
# Processing Record 47 of Set 9 | borovskoy
# Processing Record 48 of Set 9 | sanary-sur-mer
# Processing Record 49 of Set 9 | calcutta
# Processing Record 50 of Set 9 | ahipara
# Processing Record 1 of Set 10 | merauke
# Processing Record 2 of Set 10 | nesbyen
# Processing Record 3 of Set 10 | kargasok
# Processing Record 4 of Set 10 | gunnedah
# Processing Record 5 of Set 10 | inta
# Processing Record 6 of Set 10 | zhongxing
# Processing Record 7 of Set 10 | mount gambier
# Processing Record 8 of Set 10 | danville
# Processing Record 9 of Set 10 | sri aman
# Processing Record 10 of Set 10 | den helder
# Processing Record 11 of Set 10 | de aar
# Processing Record 12 of Set 10 | tabuk
# Processing Record 13 of Set 10 | shenjiamen
# Processing Record 14 of Set 10 | port hardy
# Processing Record 15 of Set 10 | san lorenzo
# Processing Record 16 of Set 10 | scarborough
# Processing Record 17 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 18 of Set 10 | mujiayingzi
# Processing Record 19 of Set 10 | matay
# Processing Record 20 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 10 | mulanje
# Processing Record 22 of Set 10 | chivacoa
# Processing Record 23 of Set 10 | goderich
# Processing Record 24 of Set 10 | russell
# Processing Record 25 of Set 10 | cheremisinovo
# Processing Record 26 of Set 10 | larap
# Processing Record 27 of Set 10 | milkovo
# Processing Record 28 of Set 10 | bom jesus da lapa
# Processing Record 29 of Set 10 | santa cruz cabralia
# Processing Record 30 of Set 10 | simao
# Processing Record 31 of Set 10 | namasuba
# Processing Record 32 of Set 10 | bucerias
# Processing Record 33 of Set 10 | riverton
# Processing Record 34 of Set 10 | kamaishi
# Processing Record 35 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 36 of Set 10 | margate
# Processing Record 37 of Set 10 | guantanamo
# Processing Record 38 of Set 10 | hagere hiywet
# Processing Record 39 of Set 10 | nanortalik
# Processing Record 40 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 41 of Set 10 | maningrida
# Processing Record 42 of Set 10 | ciudad guayana
# Processing Record 43 of Set 10 | elat
# Processing Record 44 of Set 10 | storforshei
# Processing Record 45 of Set 10 | puerto rico
# Processing Record 46 of Set 10 | catalina
# Processing Record 47 of Set 10 | san ciro de acosta
# Processing Record 48 of Set 10 | oranjemund
# Processing Record 49 of Set 10 | ibia
# Processing Record 50 of Set 10 | haapiti
# Processing Record 1 of Set 11 | coihaique
# Processing Record 2 of Set 11 | puerto carreno
# Processing Record 3 of Set 11 | olean
# Processing Record 4 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 6 of Set 11 | sao gabriel
# Processing Record 7 of Set 11 | batagay-alyta
# Processing Record 8 of Set 11 | kahului
# Processing Record 9 of Set 11 | novaya ladoga
# Processing Record 10 of Set 11 | liwale
# Processing Record 11 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 11 | havre
# Processing Record 14 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 15 of Set 11 | abu zabad
# Processing Record 16 of Set 11 | kosh-agach
# Processing Record 17 of Set 11 | isla mujeres
# Processing Record 18 of Set 11 | konstantinovka
# Processing Record 19 of Set 11 | kangaatsiaq
# Processing Record 20 of Set 11 | codrington
# Processing Record 21 of Set 11 | mahon
# Processing Record 22 of Set 11 | nioro
# Processing Record 23 of Set 11 | ankpa
# Processing Record 24 of Set 11 | ust-kut
# Processing Record 25 of Set 11 | lebyazhye
# Processing Record 26 of Set 11 | magistralnyy
# Processing Record 27 of Set 11 | garowe
# Processing Record 28 of Set 11 | denpasar
# Processing Record 29 of Set 11 | wanlaweyn
# Processing Record 30 of Set 11 | ngorongoro
# Processing Record 31 of Set 11 | manicore
# Processing Record 32 of Set 11 | jhelum
# Processing Record 33 of Set 11 | porbandar
# Processing Record 34 of Set 11 | vysokogornyy
# Processing Record 35 of Set 11 | aklavik
# Processing Record 36 of Set 11 | broken hill
# Processing Record 37 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 11 | pristen
# Processing Record 39 of Set 11 | cap malheureux
# Processing Record 40 of Set 11 | ust-maya
# Processing Record 41 of Set 11 | svetlyy
# Processing Record 42 of Set 11 | roma
# Processing Record 43 of Set 11 | san jose
# Processing Record 44 of Set 11 | umuarama
# Processing Record 45 of Set 11 | dudinka
# Processing Record 46 of Set 11 | visby
# Processing Record 47 of Set 11 | flin flon
# Processing Record 48 of Set 11 | atbasar
# Processing Record 49 of Set 11 | warri
# Processing Record 50 of Set 11 | kose
# Processing Record 1 of Set 12 | chilca
# Processing Record 2 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 12 | urusha
# Processing Record 4 of Set 12 | reconquista
# Processing Record 5 of Set 12 | revelstoke
# Processing Record 6 of Set 12 | dagana
# Processing Record 7 of Set 12 | lurgan
# Processing Record 8 of Set 12 | tabou
# Processing Record 9 of Set 12 | san luis
# Processing Record 10 of Set 12 | seoul
# Processing Record 11 of Set 12 | santa lucia
# Processing Record 12 of Set 12 | teknaf
# Processing Record 13 of Set 12 | salamanca
# Processing Record 14 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 12 | jalu
# Processing Record 16 of Set 12 | ca mau
# Processing Record 17 of Set 12 | nome
# Processing Record 18 of Set 12 | escanaba
# Processing Record 19 of Set 12 | broome
# Processing Record 20 of Set 12 | shimoda
# Processing Record 21 of Set 12 | dombas
# Processing Record 22 of Set 12 | ziarat
# Processing Record 23 of Set 12 | kologriv
# Processing Record 24 of Set 12 | mangrol
# Processing Record 25 of Set 12 | baherden
# Processing Record 26 of Set 12 | karachi
# Processing Record 27 of Set 12 | sisimiut
# Processing Record 28 of Set 12 | atar
# Processing Record 29 of Set 12 | tilichiki
# Processing Record 30 of Set 12 | barentu
# Processing Record 31 of Set 12 | bardiyah
# Processing Record 32 of Set 12 | takapau
# Processing Record 33 of Set 12 | lubango
# Processing Record 34 of Set 12 | rouvroy
# Processing Record 35 of Set 12 | north bend
# Processing Record 36 of Set 12 | perth
# Processing Record 37 of Set 12 | manokwari
# Processing Record 38 of Set 12 | sechura
# Processing Record 39 of Set 12 | koumac
# Processing Record 40 of Set 12 | madimba
# Processing Record 41 of Set 12 | vila velha
# Processing Record 42 of Set 12 | dondo
# Processing Record 43 of Set 12 | pueblo
# Processing Record 44 of Set 12 | auki
# Processing Record 45 of Set 12 | panaba
# Processing Record 46 of Set 12 | tarata
# Processing Record 47 of Set 12 | guane
# Processing Record 48 of Set 12 | bushenyi
# Processing Record 49 of Set 12 | lydenburg
# Processing Record 50 of Set 12 | udachnyy
# Processing Record 1 of Set 13 | hajnowka
# Processing Record 2 of Set 13 | maholi
# Processing Record 3 of Set 13 | aitape
# Processing Record 4 of Set 13 | bubaque
# Processing Record 5 of Set 13 | marystown
# Processing Record 6 of Set 13 | kalmunai
# Processing Record 7 of Set 13 | wamba
# Processing Record 8 of Set 13 | itacoatiara
# Processing Record 9 of Set 13 | fairmont
# Processing Record 10 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 11 of Set 13 | sai buri
# Processing Record 12 of Set 13 | engen
# Processing Record 13 of Set 13 | tubinskiy
# Processing Record 14 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 13 | pontes e lacerda
# Processing Record 16 of Set 13 | kimry
# Processing Record 17 of Set 13 | saint-die
# City not found. Skipping...
# Processing Record 18 of Set 13 | maarianhamina
# Processing Record 19 of Set 13 | miri
# Processing Record 20 of Set 13 | ramnagar
# Processing Record 21 of Set 13 | ormstown
# Processing Record 22 of Set 13 | kabelvag
# Processing Record 23 of Set 13 | san pedro
# Processing Record 24 of Set 13 | bereznik
# Processing Record 25 of Set 13 | maraa
# Processing Record 26 of Set 13 | staunton
# Processing Record 27 of Set 13 | pasighat
# Processing Record 28 of Set 13 | skelleftea
# Processing Record 29 of Set 13 | eureka
# Processing Record 30 of Set 13 | cabras
# Processing Record 31 of Set 13 | santo augusto
# Processing Record 32 of Set 13 | yerbogachen
# Processing Record 33 of Set 13 | abnub
# Processing Record 34 of Set 13 | parvatipuram
# Processing Record 35 of Set 13 | mount holly
# Processing Record 36 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 13 | sept-iles
# Processing Record 38 of Set 13 | buala
# Processing Record 39 of Set 13 | azul
# Processing Record 40 of Set 13 | ocher
# Processing Record 41 of Set 13 | kardla
# Processing Record 42 of Set 13 | springbok
# Processing Record 43 of Set 13 | aykhal
# Processing Record 44 of Set 13 | bridlington
# Processing Record 45 of Set 13 | xining
# Processing Record 46 of Set 13 | jumla
# Processing Record 47 of Set 13 | sao joao da barra
# Processing Record 48 of Set 13 | kollam
# Processing Record 49 of Set 13 | mayskiy
# Processing Record 50 of Set 13 | shingu
# Processing Record 1 of Set 14 | arrifes
# Processing Record 2 of Set 14 | pemba
# Processing Record 3 of Set 14 | octeville
# Processing Record 4 of Set 14 | coffs harbour
# Processing Record 5 of Set 14 | jieshi
# Processing Record 6 of Set 14 | bay roberts
# Processing Record 7 of Set 14 | qaqortoq
# Processing Record 8 of Set 14 | los llanos de aridane
# Processing Record 9 of Set 14 | ginda
# Processing Record 10 of Set 14 | bressanone
# Processing Record 11 of Set 14 | pascagoula
# Processing Record 12 of Set 14 | ormara
# Processing Record 13 of Set 14 | erzin
# Processing Record 14 of Set 14 | talara
# Processing Record 15 of Set 14 | moose factory
# Processing Record 16 of Set 14 | vitim
# Processing Record 17 of Set 14 | winschoten
# Processing Record 18 of Set 14 | buin
# Processing Record 19 of Set 14 | kawalu
# Processing Record 20 of Set 14 | homer
# Processing Record 21 of Set 14 | belmonte
# Processing Record 22 of Set 14 | mirnyy
# Processing Record 23 of Set 14 | venice
# Processing Record 24 of Set 14 | veere
# Processing Record 25 of Set 14 | sonamura
# Processing Record 26 of Set 14 | general roca
# Processing Record 27 of Set 14 | pacific grove
# Processing Record 28 of Set 14 | byron bay
# Processing Record 29 of Set 14 | kavaratti
# Processing Record 30 of Set 14 | male
# Processing Record 31 of Set 14 | ishigaki
# Processing Record 32 of Set 14 | beatrice
# Processing Record 33 of Set 14 | skeldon
# Processing Record 34 of Set 14 | goundi
# Processing Record 35 of Set 14 | pavilosta
# Processing Record 36 of Set 14 | geraldton
# Processing Record 37 of Set 14 | la paz
# Processing Record 38 of Set 14 | zavodoukovsk
# Processing Record 39 of Set 14 | wittingen
# Processing Record 40 of Set 14 | puerto escondido
# Processing Record 41 of Set 14 | salinopolis
# Processing Record 42 of Set 14 | westport
# Processing Record 43 of Set 14 | san andres
# Processing Record 44 of Set 14 | qinhuangdao
# Processing Record 45 of Set 14 | kruisfontein
# Processing Record 46 of Set 14 | kryvyy rih
# Processing Record 47 of Set 14 | warrnambool
# Processing Record 48 of Set 14 | olinda
# Processing Record 49 of Set 14 | korla
# Processing Record 50 of Set 14 | dolinsk
# Processing Record 1 of Set 15 | kholodnyy
# Processing Record 2 of Set 15 | salto del guaira
# Processing Record 3 of Set 15 | imbituba
# Processing Record 4 of Set 15 | burnie
# Processing Record 5 of Set 15 | bontang
# Processing Record 6 of Set 15 | fonte boa
# Processing Record 7 of Set 15 | japura
# Processing Record 8 of Set 15 | verkhniy baskunchak
# Processing Record 9 of Set 15 | knysna
# Processing Record 10 of Set 15 | zhuhai
# Processing Record 11 of Set 15 | kokuy
# Processing Record 12 of Set 15 | eyemouth
# Processing Record 13 of Set 15 | port macquarie
# Processing Record 14 of Set 15 | mindelo
# Processing Record 15 of Set 15 | bandarbeyla
# Processing Record 16 of Set 15 | ha tinh
# Processing Record 17 of Set 15 | ninh binh
# Processing Record 18 of Set 15 | mumford
# Processing Record 19 of Set 15 | lubon
# Processing Record 20 of Set 15 | kutum
# Processing Record 21 of Set 15 | zastron
# Processing Record 22 of Set 15 | lingyuan
# Processing Record 23 of Set 15 | huilong
# Processing Record 24 of Set 15 | waverley
# Processing Record 25 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 26 of Set 15 | canandaigua
# Processing Record 27 of Set 15 | patnanungan
# Processing Record 28 of Set 15 | new waterford
# Processing Record 29 of Set 15 | acobamba
# Processing Record 30 of Set 15 | sheksna
# Processing Record 31 of Set 15 | manzil tamim
# City not found. Skipping...
# Processing Record 32 of Set 15 | ambovombe
# Processing Record 33 of Set 15 | tigil
# Processing Record 34 of Set 15 | porto seguro
# Processing Record 35 of Set 15 | dwarka
# Processing Record 36 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 15 | miklavz na dravskem polju
# Processing Record 38 of Set 15 | camacha
# Processing Record 39 of Set 15 | namatanai
# Processing Record 40 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 15 | kirakira
# Processing Record 42 of Set 15 | paranhos
# Processing Record 43 of Set 15 | methoni
# Processing Record 44 of Set 15 | juneau
# Processing Record 45 of Set 15 | waingapu
# Processing Record 46 of Set 15 | mudanjiang
# Processing Record 47 of Set 15 | fayetteville
# Processing Record 48 of Set 15 | zhigansk
# Processing Record 49 of Set 15 | saint anthony
# Processing Record 50 of Set 15 | sochaczew
# Processing Record 1 of Set 16 | bykovo
# Processing Record 2 of Set 16 | leshukonskoye
# Processing Record 3 of Set 16 | yellandu
# Processing Record 4 of Set 16 | hanzhong
# Processing Record 5 of Set 16 | igrim
# Processing Record 6 of Set 16 | santa cruz
# Processing Record 7 of Set 16 | oudtshoorn
# Processing Record 8 of Set 16 | edd
# Processing Record 9 of Set 16 | wolfsberg
# Processing Record 10 of Set 16 | jasper
# Processing Record 11 of Set 16 | qianan
# Processing Record 12 of Set 16 | cleethorpes
# Processing Record 13 of Set 16 | pedasi
# Processing Record 14 of Set 16 | vaitape
# Processing Record 15 of Set 16 | richards bay
# Processing Record 16 of Set 16 | san quintin
# Processing Record 17 of Set 16 | tecolutla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 708

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hermanus -34.4187   19.2345     77.81        47         100
# 1  Port Elizabeth -33.9180   25.5701     71.10        87           0
# 2           Airai  -8.9266  125.4092     61.38        86         100
# 3       Ostrovnoy  68.0531   39.5131     39.25        89          33
# 4      Bredasdorp -34.5322   20.0403     67.55        65         100
# 5     Yellowknife  62.4560 -114.3525     54.12        66          75
# 6        La Ronge  55.1001 -105.2842     64.62        36          20
# 7    Longyearbyen  78.2186   15.6401     33.64        80          75
# 8  Saint-Philippe -21.3585   55.7679     72.99        77          39
# 9        Havelock  34.8791  -76.9013     73.98        54          20
#
#    Wind Speed Country Current Description
# 0       12.01      ZA     overcast clouds
# 1       20.71      ZA           clear sky
# 2        2.26      TL          light rain
# 3       15.84      RU    scattered clouds
# 4        8.97      ZA     overcast clouds
# 5       10.36      CA       broken clouds
# 6       13.80      CA          few clouds
# 7        2.30      SJ       broken clouds
# 8        9.66      RE    scattered clouds
# 9        9.22      US          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Hermanus      ZA -34.4187   19.2345     77.81        47
# 1    Port Elizabeth      ZA -33.9180   25.5701     71.10        87
# 2             Airai      TL  -8.9266  125.4092     61.38        86
# 3         Ostrovnoy      RU  68.0531   39.5131     39.25        89
# 4        Bredasdorp      ZA -34.5322   20.0403     67.55        65
# ..              ...     ...      ...       ...       ...       ...
# 703          Pedasi      PA   7.5333  -80.0333     81.68        74
# 704         Vaitape      PF -16.5167 -151.7500     77.94        76
# 705    Richards Bay      ZA -28.7830   32.0377     70.47        90
# 706     San Quintin      MX  30.4833 -115.9500     72.50        73
# 707       Tecolutla      MX  20.4833  -97.0167     75.81        81
#
#      Cloudiness  Wind Speed Current Description
# 0           100       12.01     overcast clouds
# 1             0       20.71           clear sky
# 2           100        2.26          light rain
# 3            33       15.84    scattered clouds
# 4           100        8.97     overcast clouds
# ..          ...         ...                 ...
# 703          92        2.82     overcast clouds
# 704           8       17.72           clear sky
# 705          67        7.18       broken clouds
# 706          34       10.25    scattered clouds
# 707          96       10.27     overcast clouds
#
# [708 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
